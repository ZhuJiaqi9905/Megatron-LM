# %% [markdown]
# 根据A10G和L40S的结果，得到GPT2-6B在4096的sequence length之下的不均匀切分数据时候，能得到比均匀切分更好的结果。

# %%
import torch 
import json
from typing import Dict, List

# %%
# read data from file
model_compute = {}
for device in ["A10G", "L40S"]:
    model_compute.setdefault(device, {})
    for tp in [1, 2, 4, 8]:
        file = f"../metis/GPT_2-6B/4096/DeviceType.{device}_tp{tp}_bs2.json"
        try:
            with open(file, 'r') as f:
                data = json.load(f)
        except FileNotFoundError:
            print("The file was not found.")
            exit()
        except json.JSONDecodeError:
            print("The file does not contain valid JSON.")
            exit()
        model_compute[device][tp] = data["execution_time"]["layer_compute_total_ms"]

print(model_compute)
# Out:
# {'A10G': {1: [4.830085067749024, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 81.83101318359375, 145.37521484375], 2: [74.28806396484374, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 128.145751953125], 4: [99.52864013671875, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 315.58, 109.902666015625], 8: [112.48007080078125, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 358.8165234375, 114.978857421875]}, 'L40S': {1: [2.7816754531860353, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 26.94828125, 56.745615234375], 2: [22.908251953125, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 44.271943359375], 4: [23.7720166015625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 68.63943603515625, 30.1365869140625], 8: [37.211114501953126, 121.2525390625, 121.2525390625, 121.2525390625, 121.2525390625, 121.2525390625, 121.2525390625, 121.2525390625, 12 ...

# %% [markdown]
# TP = 2相当于不开TP，但是CP处理2K的sequence。

# %%
print(f"A10G: {model_compute['A10G'][2]}")
num_layers = len(model_compute['A10G'][2])
print(f"L40S: {model_compute['L40S'][2]}")
print(f"num_layers: {num_layers}")

cp_balance_layer_time = []
cp_imbalance_layer_time = []
for i in range(num_layers):
    cp_balance_layer_time.append(max(model_compute['A10G'][2][i], model_compute['L40S'][2][i]))
    cp_imbalance_layer_time.append(max(model_compute['A10G'][2][i] / 2, model_compute['L40S'][2][i]) * 3 / 2)

balance_stage_time = [sum(cp_balance_layer_time[: num_layers // 2]), sum(cp_balance_layer_time[num_layers // 2:])]
imbalance_stage_time = [sum(cp_imbalance_layer_time[: num_layers // 2]), sum(cp_imbalance_layer_time[num_layers // 2:])]

print(f"balance: {balance_stage_time}, imbalance: {imbalance_stage_time}")
# Out:
# A10G: [74.28806396484374, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 234.081806640625, 128.145751953125]
# L40S: [22.908251953125, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 68.8536572265625, 44.271943359375]
# num_layers: 34
# balance: [3819.5969702148436, 3873.454658203125], imbalance: [2864.697727661133, 2905.0909936523435]

# %%
def pp_iteration_time(stage_time_ms:List[float], nums_of_mbs: int) -> float:
    '''
    Unit in s.
    '''
    
    bottle_stage_time = max(stage_time_ms)
    bottle_stage = stage_time_ms.index(bottle_stage_time) 
    
    num_stages = len(stage_time_ms)
    steady_time = (nums_of_mbs - num_stages + bottle_stage) * bottle_stage_time + (num_stages - bottle_stage - 1) * (2 * bottle_stage_time / 3)
    total_time = steady_time + sum(stage_time_ms)

    return total_time / 1000

# %%
gbs = 1024
mbs = 2
nums_of_mbs = gbs / mbs
balance_time = pp_iteration_time(balance_stage_time, nums_of_mbs)

imbalance_time = pp_iteration_time(imbalance_stage_time, nums_of_mbs)
print(f"balance_time: {balance_time}, imbalance_time: {imbalance_time}")
# Out:
# balance_time: 1987.028381970215, imbalance_time: 1490.271286477661

# %% [markdown]
# 读取数据后，计算不同配置下的运行时间

# %%
def split_to_powers_of_two(n:int) -> List[int]:
    powers = []
    while n > 0:
        power = 1
        while power * 2 <= n:
            power *= 2
        powers.append(power)
        n -= power
    return powers

def get_iteration_time_per_mbs(model_compute: Dict[str, Dict[int, List[float]]], device: str, bs: int) -> int:
    '''
    Return the iteration time. Unit s.
    '''
    splited_bs = split_to_powers_of_two(bs)
    total_time = 0
    for bs in splited_bs:
        total_time += sum(model_compute[device][bs]) / 1000
    
    return total_time

# %%
balance_time_per_mbs = max(get_iteration_time_per_mbs(model_compute, "A10G", 2), get_iteration_time_per_mbs(model_compute, "L40S", 2))
imbalance_time_per_mbs = max(get_iteration_time_per_mbs(model_compute, "A10G", 1), get_iteration_time_per_mbs(model_compute, "L40S", 3))
gbs = 1024
mbs = 4
balance_time = balance_time_per_mbs * gbs / mbs
imbalance_time = imbalance_time_per_mbs * gbs / mbs
print(f"balance: {balance_time}, imbalance: {imbalance_time}")
# Out:
# balance: 1969.4212168749982, imbalance: 980.8172337500004
